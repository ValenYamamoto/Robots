# %%
import pandas
import seaborn as sns
from matplotlib.lines import Line2D
import matplotlib.pyplot as plt
import df_operations

# %%
df1 = df_operations.read_pickle( "0311-1237-pytorch-reward.p" )
df1.head()
# Out:
#         0         1          2         3         4         5         6    \
# 0  0.033945 -0.409982   0.690132  0.954253 -0.453314  0.949974 -0.389479
# 1 -0.740904 -0.085048 -50.000000  0.441922  0.117898  0.988058  0.901898
# 2  0.781417  0.141885  -0.295103  0.117086  0.510391 -0.052321 -0.503551
# 3  0.564312 -0.109363   0.262126 -0.373592  0.881035  0.843597  0.759937
# 4  0.324493  0.630994   0.763276  0.629219  0.437734  0.500363 -1.085869
#
#         7          8         9    ...        118        119       120  \
# 0  0.623905   0.807337  0.504536  ...  -0.207994   0.397012  0.935551
# 1  0.192212   0.692761 -0.272896  ... -50.000000 -50.000000  0.944027
# 2  0.896760 -50.000000 -0.031018  ...  -1.028622 -50.000000  0.303719
# 3 -0.278095   0.331361  0.680860  ...  -0.453308  -0.374270  0.327014
# 4  0.630325   0.983685  0.073975  ...  -0.039234  -0.692906  0.749867
#
#          121       122       123        124       125        126        127
# 0   0.541308  0.280781  0.643678 -50.000000 -0.595236 -50.000000  -0.386668
# 1   0.442593  0.857253  0.856487   0.473023  0.076154   0.331422 -50.000000
# 2   0.831103 -0.946290  0.748381   0.477912  0.734136  -0.381941   0.635144
# 3 -50.000000  0.545084  0.660564 -50.000000  0.584488   0.515513   0.550857
# 4   0.036662  0.649892 -0.216453   0.569639  0.666831   0.874494   0.781710
#
# [5 rows x 128 columns]

# %%
arr = df1.iloc[ 1 ].to_numpy()
plt.hist( arr, bins=[-51, -49, -1.5, -0.5, 0, 0.5, 1, 2, 99, 100] )
# Out:
# (array([11.,  0., 17., 19., 33., 47.,  0.,  0.,  1.]),
#  array([-51. , -49. ,  -1.5,  -0.5,   0. ,   0.5,   1. ,   2. ,  99. ,
#         100. ]),
#  <BarContainer object of 9 artists>)
